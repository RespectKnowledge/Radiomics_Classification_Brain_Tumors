# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/My Drive'
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
#  174616_394223_bundle_archive/      best_model.14-0.47.h5
#  174616_394223_bundle_archive.zip   best_model.15-0.45.h5
# 'AQayyumCV_2020 (1).pdf'            best_model.15-0.49.h5
#  AQayyumCV_2020.pdf                 best_model.17-0.49.h5
#  AQ_paper_V1.docx                   best_modellstmmulti.01-0.50.h5
#  best_model.01-0.24.h5              best_modellstmmulti.01-0.58.h5
#  best_model.01-0.64.h5              best_modellstmmulti.01-0.60.h5
#  best_model.01-0.65.h5              best_modellstmmulti.01-0.66.h5
#  best_model.01-0.66.h5              best_modellstmmulti.01-0.68.h5
#  best_model.01-0.69.h5              best_modellstmmulti.01-0.84.h5
#  best_model.02-0.18.h5              best_modellstmmulti.02-0.48.h5
#  best_model.02-0.62.h5              best_modellstmmulti.02-0.54.h5
#  best_model.02-0.63.h5              best_modellstmmulti.02-0.60.h5
#  best_model.02-0.67.h5              best_modellstmmulti.02-0.63.h5
#  best_model.03-0.14.h5              best_modellstmmulti.02-0.67.h5
#  best_model.03-0.60.h5              best_modellstmmulti.02-0.80.h5
#  best_model.03-0.61.h5              best_modellstmmulti.03-0.46.h5
#  best_model.03-0.62.h5              best_modellstmmulti.03-0.49.h5
#  best_model.03-0.66.h5              best_modellstmmulti.03-0.58.h5
#  best_model.04-0.11.h5              best_modellstmmulti.03-0.60.h5
#  best_model.04-0.59.h5              best_modellstmmulti.03-0.66.h5
#  best_model.04-0.60.h5              best_modellstmmulti.03-0.77.h5
#  best_model.04-0.61.h5              best_modellstmmulti.04-0.43.h5
#  best_model.04-0.64.h5              best_modellstmmulti.04-0.55.h5
#  best_model.05-0.58.h5              best_modellstmmulti.04-0.60.h5
#  best_model.05-0.59.h5              best_modellstmmulti.04-0.64.h5
#  best_model.05-0.60.h5              best_modellstmmulti.04-0.74.h5
#  best_model.05-0.63.h5              best_modellstmmulti.05-0.53.h5
#  best_model.06-0.57.h5              best_modellstmmulti.05-0.60.h5
#  best_model.06-0.59.h5              best_modellstmmulti.05-0.62.h5
#  best_model.06-0.60.h5              best_modellstmmulti.05-0.73.h5
#  best_model.06-0.63.h5              best_modellstmmulti.06-0.52.h5
#  best_model.07-0.56.h5              best_modellstmmulti.06-0.62.h5
#  best_model.07-0.58.h5              best_modellstmmulti.06-0.72.h5
#  best_model.07-0.59.h5              best_modellstmmulti.07-0.51.h5
#  best_model.07-0.62.h5              best_modellstmmulti.07-0.71.h5
#  best_model.08-0.55.h5              best_modellstmmulti.08-0.70.h5
#  best_model.08-0.58.h5              best_modellstmmulti.09-0.41.h5
#  best_model.08-0.61.h5              best_modellstmmulti.09-0.62.h5
#  best_model.09-0.54.h5              best_modellstmmulti.09-0.70.h5
#  best_model.09-0.57.h5              best_modellstmmulti.10-0.35.h5
#  best_model.09-0.61.h5              best_modellstmmulti.10-0.61.h5
#  best_model.10-0.52.h5              best_modellstmmulti.10-0.69.h5
#  best_model.10-0.55.h5              best_modellstmmulti.11-0.69.h5
#  best_model1.01-0.53.h5             best_modellstmmulti.12-0.68.h5
#  best_model1.01-0.59.h5             best_modellstmmulti.13-0.68.h5
#  best_model1.01-0.66.h5             best_modellstmmulti.14-0.67.h5
#  best_model1.01-0.67.h5             best_modellstmmulti.15-0.67.h5
#  best_model1.01-0.68.h5             best_modellstmmulti.16-0.67.h5
#  best_model1.01-0.69.h5             best_modellstmmulti.17-0.66.h5
#  best_model1.02-0.37.h5             best_modellstmmulti.18-0.66.h5
#  best_model1.02-0.51.h5             best_modellstmmulti.19-0.66.h5
#  best_model1.02-0.54.h5             best_modellstmmulti.20-0.66.h5
#  best_model1.02-0.57.h5             best_modellstmmulti.21-0.65.h5
#  best_model1.02-0.59.h5             best_modellstmmulti.22-0.65.h5
#  best_model1.02-0.67.h5             best_modellstmmulti.23-0.65.h5
#  best_model1.03-0.26.h5             best_modellstmmulti.24-0.65.h5
#  best_model1.03-0.40.h5             best_modellstmmulti.25-0.65.h5
#  best_model1.03-0.41.h5             best_modellstmmulti.26-0.65.h5
#  best_model1.03-0.54.h5             best_modellstmmulti.27-0.65.h5
#  best_model1.03-0.55.h5             best_modellstmmulti.28-0.65.h5
#  best_model1.03-0.65.h5             best_modellstmmulti.30-0.65.h5
#  best_model1.04-0.24.h5             best_modellstmmulti.31-0.64.h5
#  best_model1.04-0.29.h5             best_modellstmmulti.32-0.64.h5
#  best_model1.04-0.31.h5             best_modellstmmulti.33-0.64.h5
#  best_model1.04-0.40.h5             best_modellstmmulti.34-0.64.h5
#  best_model1.04-0.57.h5             best_modellstmmulti.35-0.63.h5
#  best_model1.05-0.20.h5             best_modellstmmulti.36-0.63.h5
#  best_model1.05-0.22.h5             best_modellstmmulti.37-0.63.h5
#  best_model1.05-0.23.h5             best_modellstmmulti.38-0.63.h5
#  best_model1.05-0.28.h5             best_modellstmmulti.39-0.62.h5
#  best_model1.05-0.43.h5             best_modellstmmulti.40-0.62.h5
#  best_model1.05-0.48.h5             best_modellstmmulti.41-0.62.h5
#  best_model1.06-0.17.h5             best_modellstmmulti.42-0.62.h5
#  best_model1.06-0.18.h5             best_modellstmmulti.43-0.61.h5
#  best_model1.06-0.20.h5             best_modellstmmulti.44-0.61.h5
#  best_model1.06-0.22.h5             best_modellstmmulti.45-0.61.h5
#  best_model1.06-0.31.h5             best_modellstmmulti.46-0.61.h5
#  best_model1.06-0.46.h5             best_modellstmmulti.47-0.61.h5
#  best_model1.07-0.14.h5             best_modellstmmulti.48-0.61.h5
#  best_model1.07-0.16.h5             best_modellstmmulti.49-0.61.h5
#  best_model1.07-0.19.h5             best_modellstmmulti.50-0.61.h5
#  best_model1.07-0.21.h5            'Colab Notebooks'/
#  best_model1.07-0.33.h5             data/
#  best_model1.08-0.25.h5             dataset/
#  best_model1.08-0.32.h5             Depressiontraintestdataset/
#  best_model1.09-0.12.h5             Depressiontraintestdataset.zip
#  best_model1.09-0.16.h5             example_data/
#  best_model1.09-0.18.h5             heartGAN/
#  best_model1.09-0.23.h5             HeartGANnew/
#  best_model1.10-0.12.h5             HeartGANnew.zip
#  best_model1.10-0.15.h5             heartGAN.zip
#  best_model.11-0.51.h5              logs/
#  best_model.11-0.54.h5              mnist_train/
#  best_model1.11-0.13.h5             Mycardiumtrain/
#  best_model1.12-0.13.h5             Mycardiumtrain.zip
#  best_model1.12-0.22.h5             Myotrainingmask/
#  best_model1.13-0.11.h5             MyotrainingmaskGAN.zip
#  best_model1.13-0.16.h5             Myotrainingmask.zip
#  best_model1.15-0.12.h5            'Professional_Summary (1).docx'
#  best_model1.15-0.14.h5             Professional_Summary.docx
#  best_model1.16-0.09.h5             RNNmodel.zip
#  best_model1.17-0.09.h5             runs/
#  best_model1.20-0.08.h5             SegThor2019dataset.zip
#  best_model.12-0.50.h5              torch_data/
#  best_model.12-0.52.h5              train.zip
#  best_model1.24-0.08.h5            'Untitled drawing (1).gdraw'
#  best_model1.25-0.07.h5            'Untitled drawing (2).gdraw'
#  best_model1.27-0.07.h5            'Untitled drawing - Bar chart 1.gsheet'
#  best_model1.29-0.05.h5            'Untitled drawing - Column chart 2.gsheet'
#  best_model.13-0.47.h5             'Untitled drawing.gdraw'
#  best_model.13-0.52.h5             'Video 1.zip'

# %% [markdown]
# **Brain tumor classification using radiomics features.**
#
# Please download dataset from brats2018 challenge and upload in google drive
#
# install radiomics library and extract some features

# %%
#!pip install pyradiomics

# %%
#%%  brain Tumor classification using radiomics features
import os
import pandas as pd
import numpy as np
import logging
from radiomics import featureextractor
import radiomics
import six, numpy as np    
import SimpleITK as sitk

#from radiomics import getTestCase

# %%
# define some sitting before feature extraction
settings = {}
settings['binWidth'] = 25
settings['resampledPixelSpacing'] = None
settings['interpolator'] = 'sitkBSpline'
settings['verbose'] = True

# provide path of dataset for HGG and LGG class
# image path
impathH='D:\\Moonaradiomics\\MICCAI_BraTS_2018_Data_Training\\HGG'
listdrH=os.listdir(impathH)
# feature append as list
elongation = []
flatness = []
patient_id = []
elongation = []
flatness = []
majAL = []
minAL = []
threedimdiam = []
spher = []
surfArea = []
energ = []
entrop = []
kurt = []
mean = []
skew = []
cont = []
correl = []
idm = []
coarse = []
complexity = []
strength = []
y_labels = []
case_id=[]

for i in listdrH:
    highglom=os.path.join(impathH,i)
    imgh=os.path.join(highglom,i+'_t1'+'.nii') # we are only extracted t1 sequence features here
    maskh=os.path.join(highglom,i+'_seg'+'.nii') # load segmentation map
    img_h=sitk.ReadImage(imgh)
    mask_h=sitk.ReadImage(maskh)
    print(highglom)
    extractor = featureextractor.RadiomicsFeatureExtractor(**settings)
    #print(extractor.enableFeatureClassByName('glcm'))
    featureVector = extractor.execute(img_h, mask_h)
    #print(featureVector)
    elongation.append(featureVector['original_shape_Elongation'])
    flatness.append(featureVector['original_shape_Flatness'])
    majAL.append(featureVector['original_shape_MajorAxisLength'])
    minAL.append(featureVector['original_shape_MinorAxisLength'])
    threedimdiam.append(featureVector['original_shape_Maximum3DDiameter'])
    spher.append(featureVector['original_shape_Sphericity'])
    surfArea.append(featureVector['original_shape_SurfaceArea'])
    energ.append(featureVector['original_firstorder_Energy'])
    entrop.append(featureVector['original_firstorder_Entropy'])
    kurt.append(featureVector['original_firstorder_Kurtosis'])
    mean.append(featureVector['original_firstorder_Mean'])
    skew.append(featureVector['original_firstorder_Skewness'])
    cont.append(featureVector['original_glcm_Contrast'])
    correl.append(featureVector['original_glcm_Correlation'])
    idm.append(featureVector['original_glcm_Idm'])
    coarse.append(featureVector['original_ngtdm_Coarseness'])
    complexity.append(featureVector['original_ngtdm_Complexity'])
    strength.append(featureVector['original_ngtdm_Strength'])
    y_labels.append(1)
    case_id.append(i)

# define dictionary of extracted features
raw_data = {
    'elongation':elongation,
    'flatness':flatness,
    'major_axis_length':majAL,
    'minor_axis_length':minAL,
    'max_3D_diameter':threedimdiam,
    'sphericity':spher,
    'surface_area':surfArea,
    'energy':energ,
    'entropy':entrop,
    'kurtosis':kurt,
    'mean':mean,
    'skewness':skew,
    'contrast':cont,
    'correlation':correl,
    'inverse_diff_moment':idm,
    'coarseness':coarse,
    'complexity':complexity,
    'strength':strength,
    'y_labels':y_labels
}


# save to pandas dataframe
dfh = pd.DataFrame(raw_data, index = case_id)
dfh.head()

# %%
# compute features for LGG
import os
import pandas as pd
import numpy as np
import logging
from radiomics import featureextractor
import radiomics
import six, numpy as np    
import SimpleITK as sitk

#from radiomics import getTestCase


settings = {}
settings['binWidth'] = 25
settings['resampledPixelSpacing'] = None
settings['interpolator'] = 'sitkBSpline'
settings['verbose'] = True

# image path
impathL='D:\\Moonaradiomics\\MICCAI_BraTS_2018_Data_Training\\LGG'
listdrL=os.listdir(impathL)

elongation = []
flatness = []
patient_id = []
elongation = []
flatness = []
majAL = []
minAL = []
threedimdiam = []
spher = []
surfArea = []
energ = []
entrop = []
kurt = []
mean = []
skew = []
cont = []
correl = []
idm = []
coarse = []
complexity = []
strength = []
y_labels = []
case_idl=[]
for j in listdrL:
    highgloml=os.path.join(impathL,j)
    imgl=os.path.join(highgloml,j+'_t1'+'.nii')
    maskl=os.path.join(highgloml,j+'_seg'+'.nii')
    img_l=sitk.ReadImage(imgl)
    mask_l=sitk.ReadImage(maskl)
    print(highgloml)
    extractor = featureextractor.RadiomicsFeatureExtractor(**settings)
    #print(extractor.enableFeatureClassByName('glcm'))
    featureVector = extractor.execute(img_l, mask_l)
    #print(featureVector)
    elongation.append(featureVector['original_shape_Elongation'])
    flatness.append(featureVector['original_shape_Flatness'])
    majAL.append(featureVector['original_shape_MajorAxisLength'])
    minAL.append(featureVector['original_shape_MinorAxisLength'])
    threedimdiam.append(featureVector['original_shape_Maximum3DDiameter'])
    spher.append(featureVector['original_shape_Sphericity'])
    surfArea.append(featureVector['original_shape_SurfaceArea'])
    energ.append(featureVector['original_firstorder_Energy'])
    entrop.append(featureVector['original_firstorder_Entropy'])
    kurt.append(featureVector['original_firstorder_Kurtosis'])
    mean.append(featureVector['original_firstorder_Mean'])
    skew.append(featureVector['original_firstorder_Skewness'])
    cont.append(featureVector['original_glcm_Contrast'])
    correl.append(featureVector['original_glcm_Correlation'])
    idm.append(featureVector['original_glcm_Idm'])
    coarse.append(featureVector['original_ngtdm_Coarseness'])
    complexity.append(featureVector['original_ngtdm_Complexity'])
    strength.append(featureVector['original_ngtdm_Strength'])
    y_labels.append(0)
    case_idl.append(j)

raw_data = {
    'elongation':elongation,
    'flatness':flatness,
    'major_axis_length':majAL,
    'minor_axis_length':minAL,
    'max_3D_diameter':threedimdiam,
    'sphericity':spher,
    'surface_area':surfArea,
    'energy':energ,
    'entropy':entrop,
    'kurtosis':kurt,
    'mean':mean,
    'skewness':skew,
    'contrast':cont,
    'correlation':correl,
    'inverse_diff_moment':idm,
    'coarseness':coarse,
    'complexity':complexity,
    'strength':strength,
    'y_labels':y_labels
}

# save to pandas dataframe
dfl = pd.DataFrame(raw_data, index = case_idl)
dfl.head()

# %%
# combine two class features
df_combine = pd.concat([dfh, dfl], axis = 0)
# drop labels
y = df_combine[['y_labels']]
df= df_combine.drop(['y_labels'], axis=1)

# prerpocess and normalize labels
from sklearn import preprocessing

case_idnew1=case_id+case_idl

x = df.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
normalized_df = pd.DataFrame(x_scaled, index = case_idnew1)
normalized_df.columns = df.columns

normalized_df = pd.concat([normalized_df, y], axis = 1)
normalized_df.head()

# %%
# shuffle features 
from sklearn.utils import shuffle
shuffled = shuffle(normalized_df)
shuffled.head()

# optional step
import pandas as pd

# Save dataframe to pickled pandas object
shuffled.to_pickle('/content/drive/My Drive/data/data.pkl') # where to save it usually as a .plk

# %%
#!unzip data.zip
# Out:
# Archive:  data.zip
#   inflating: data/data.pkl

# %%
import pandas as pd
shuffled=pd.read_pickle('/content/drive/My Drive/data/data.pkl')
shuffled.head()
# Out:
#                       elongation  flatness  ...  strength  y_labels
# Brats18_TCIA01_412_1    0.547404  0.655849  ...  0.015857         1
# Brats18_TCIA08_167_1    0.678752  0.599400  ...  0.000544         1
# Brats18_CBICA_AOH_1     0.298147  0.307965  ...  0.001656         1
# Brats18_CBICA_AXM_1     0.743272  0.683038  ...  0.001945         1
# Brats18_TCIA12_101_1    0.161687  0.205773  ...  0.000999         0
#
# [5 rows x 19 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(shuffled, hue = 'y_labels')
plt.show()

# %%
plt.figure(figsize = (16,5))
sns.heatmap(shuffled.corr(), annot = True)

# %%
# split feature matrix into training(80%)and testing(20%)
from sklearn.model_selection import train_test_split
import numpy as np
X_train, X_test, y_train, y_test = train_test_split(shuffled.loc[:, 'elongation':'strength'], np.ravel(shuffled[['y_labels']]),
                                                   test_size = 0.2, random_state = 42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (228, 18)
# (57, 18)
# (228,)
# (57,)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
rf_mod = RandomForestClassifier(n_estimators=200, criterion='entropy', random_state= 10, verbose= 1)
rf_mod.fit(X_train, y_train)

print("Train score: ",rf_mod.score(X_train, y_train))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Train score:  1.0
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished

# %%
# prediction on test data
pred_rf = rf_mod.predict(X_test)
print('Test score:',rf_mod.score(X_test, y_test))
# Out:
# Test score: 0.8421052631578947
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished

# %%
# classification report using random forest
print("Classification report: ",classification_report(pred_rf,y_test))
print("Average weighted precision: ",precision_score(y_test,pred_rf))
print("Average weighted recall: ",recall_score(y_test,pred_rf))
print("Average weighted f1 score: ",f1_score(y_test,pred_rf))
# Out:
# Classification report:                precision    recall  f1-score   support
#
#            0       0.55      0.60      0.57        10
#            1       0.91      0.89      0.90        47
#
#     accuracy                           0.84        57
#    macro avg       0.73      0.75      0.74        57
# weighted avg       0.85      0.84      0.85        57
#
# Average weighted precision:  0.8936170212765957
# Average weighted recall:  0.9130434782608695
# Average weighted f1 score:  0.9032258064516129

# %%
lg_mod = LogisticRegression()
lg_mod.fit(X_train, y_train)

print("Train score: ",lg_mod.score(X_train, y_train))
# Out:
# Train score:  0.8596491228070176

# %%
pred_lg = lg_mod.predict(X_test)
print('Test score:',lg_mod.score(X_test, y_test))
# Out:
# Test score: 0.8596491228070176

# %%
print("Classification report: ",classification_report(pred_lg,y_test))
print("Average weighted precision: ",precision_score(y_test,pred_lg))
print("Average weighted recall: ",recall_score(y_test,pred_lg))
print("Average weighted f1 score: ",f1_score(y_test,pred_lg))
# Out:
# Classification report:                precision    recall  f1-score   support
#
#            0       0.45      0.71      0.56         7
#            1       0.96      0.88      0.92        50
#
#     accuracy                           0.86        57
#    macro avg       0.71      0.80      0.74        57
# weighted avg       0.89      0.86      0.87        57
#
# Average weighted precision:  0.88
# Average weighted recall:  0.9565217391304348
# Average weighted f1 score:  0.9166666666666666

# %%
"""**Gradient Boosting:**

The Gradient Boosting classifier, an ensemble technique, is based on the idea of creating several weak learners (A learner which is slightly better than random chance) to minimize loss of the model via a gradient descent like procedure. Every learner learns on a different diffcult pattern and together a majority vote predicts the target class.
"""

gb_mod = GradientBoostingClassifier(n_estimators=200, random_state= 10)
gb_mod.fit(X_train, y_train)

print("Train score: ",gb_mod.score(X_train, y_train))
# Out:
# Train score:  1.0

# %%
pred_gb = gb_mod.predict(X_test)
print('Test score:',gb_mod.score(X_test, y_test))
# Out:
# Test score: 0.8771929824561403

# %%
print("Classification report: ",classification_report(pred_gb,y_test))

print("Average weighted precision: ",precision_score(y_test,pred_gb))
print("Average weighted recall: ",recall_score(y_test,pred_gb))
print("Average weighted f1 score: ",f1_score(y_test,pred_gb))
# Out:
# Classification report:                precision    recall  f1-score   support
#
#            0       0.55      0.75      0.63         8
#            1       0.96      0.90      0.93        49
#
#     accuracy                           0.88        57
#    macro avg       0.75      0.82      0.78        57
# weighted avg       0.90      0.88      0.88        57
#
# Average weighted precision:  0.8979591836734694
# Average weighted recall:  0.9565217391304348
# Average weighted f1 score:  0.9263157894736843

# %%
"""**Gaussian Naive Bayes:**
Naive Bayes is a simple algorthim, that can predict the relative probability of a target class and thus classify them. It uses the Bayes theorem to calculate the probability of an input data point belonging to a target class [ P(target class|input) ]. It assumes there exist no correlation between the features and thus is Naive.
"""

gnb_mod = GaussianNB()
gnb_mod.fit(X_train, y_train)

print("Train score: ",gnb_mod.score(X_train, y_train))
# Out:
# Train score:  0.7543859649122807

# %%
pred_nb = gnb_mod.predict(X_test)
print('Test score:',gnb_mod.score(X_test, y_test))
# Out:
# Test score: 0.8070175438596491

# %%
print("Classification report: ",classification_report(pred_nb,y_test))

print("Average weighted precision: ",precision_score(y_test,pred_nb))
print("Average weighted recall: ",recall_score(y_test,pred_nb))
print("Average weighted f1 score: ",f1_score(y_test,pred_nb))
# Out:
# Classification report:                precision    recall  f1-score   support
#
#            0       0.27      0.50      0.35         6
#            1       0.93      0.84      0.89        51
#
#     accuracy                           0.81        57
#    macro avg       0.60      0.67      0.62        57
# weighted avg       0.87      0.81      0.83        57
#
# Average weighted precision:  0.8431372549019608
# Average weighted recall:  0.9347826086956522
# Average weighted f1 score:  0.8865979381443299

# %%
"""**Multi-Layer Perceptron:**
A Multi-Layer Perceptron classifier is a neural network classifier that applies the Error Back Propogation Training (EBPT) algorithm to learn weights for the network that suitably classify the input pattern space to target classes.
"""

mlp_mod = MLPClassifier(hidden_layer_sizes=[100,50])
mlp_mod.fit(X_train, y_train)

print("Train score: ",mlp_mod.score(X_train, y_train))
# Out:
# Train score:  0.881578947368421
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
pred_mlp = mlp_mod.predict(X_test)
print('Test score:',mlp_mod.score(X_test, y_test))
# Out:
# Test score: 0.8421052631578947

# %%
print("Classification report: ",classification_report(pred_mlp,y_test))

print("Average weighted precision: ",precision_score(y_test,pred_mlp))
print("Average weighted recall: ",recall_score(y_test,pred_mlp))
print("Average weighted f1 score: ",f1_score(y_test,pred_mlp))
# Out:
# Classification report:                precision    recall  f1-score   support
#
#            0       0.45      0.62      0.53         8
#            1       0.93      0.88      0.91        49
#
#     accuracy                           0.84        57
#    macro avg       0.69      0.75      0.72        57
# weighted avg       0.87      0.84      0.85        57
#
# Average weighted precision:  0.8775510204081632
# Average weighted recall:  0.9347826086956522
# Average weighted f1 score:  0.9052631578947369

# %%
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier
# define dataset
#X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=5)
# define the model
modelBagging = BaggingClassifier()
# fit the model on the whole dataset
#model.fit(X, y)
modelBagging.fit(X_train, y_train)

print("Train score: ",modelBagging.score(X_train, y_train))
# Out:
# Train score:  1.0

# %%
modelBaggingpred = modelBagging.predict(X_test)
print('Test score:',modelBagging.score(X_test, y_test))
# Out:
# Test score: 0.8245614035087719

# %%
print("Classification report: ",classification_report(modelBaggingpred,y_test))

print("Average weighted precision: ",precision_score(y_test,modelBaggingpred))
print("Average weighted recall: ",recall_score(y_test,modelBaggingpred))
print("Average weighted f1 score: ",f1_score(y_test,modelBaggingpred))
# Out:
# Classification report:                precision    recall  f1-score   support
#
#            0       0.73      0.53      0.62        15
#            1       0.85      0.93      0.89        42
#
#     accuracy                           0.82        57
#    macro avg       0.79      0.73      0.75        57
# weighted avg       0.82      0.82      0.82        57
#
# Average weighted precision:  0.9285714285714286
# Average weighted recall:  0.8478260869565217
# Average weighted f1 score:  0.8863636363636365

# %%
from sklearn.ensemble import ExtraTreesClassifier
ExtraTreesClassifier = ExtraTreesClassifier()

ExtraTreesClassifier.fit(X_train, y_train)

print("Train score: ",ExtraTreesClassifier.score(X_train, y_train))
# Out:
# Train score:  1.0

# %%
ExtraTreesClassifiermodel= ExtraTreesClassifier.predict(X_test)
print('Test score:',ExtraTreesClassifier.score(X_test, y_test))
# Out:
# Test score: 0.8596491228070176

# %%
print("Classification report: ",classification_report(ExtraTreesClassifiermodel,y_test))

print("Average weighted precision: ",precision_score(y_test,ExtraTreesClassifiermodel))
print("Average weighted recall: ",recall_score(y_test,ExtraTreesClassifiermodel))
print("Average weighted f1 score: ",f1_score(y_test,ExtraTreesClassifiermodel))
# Out:
# Classification report:                precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60         9
#            1       0.93      0.90      0.91        48
#
#     accuracy                           0.86        57
#    macro avg       0.74      0.78      0.76        57
# weighted avg       0.87      0.86      0.87        57
#
# Average weighted precision:  0.8958333333333334
# Average weighted recall:  0.9347826086956522
# Average weighted f1 score:  0.9148936170212766

# %%
no_skill_prob = [0 for _ in range(len(y_test))]
no_skill_auc = roc_auc_score(y_test, no_skill_prob)
print("No Skill AUC: ", no_skill_auc)
ns_fpr, ns_tpr, _ = roc_curve(y_test, no_skill_prob)
# Out:
# No Skill AUC:  0.5

# %%
# Random Forest
rf_prob = rf_mod.predict_proba(X_test)[:,-1]
rf_auc = roc_auc_score(y_test,rf_prob)
print("RandomForest AUC: ", rf_auc)
rf_fpr, rf_tpr, _ = roc_curve(y_test, rf_prob)
# Out:
# RandomForest AUC:  0.8073122529644269
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished

# %%
# Gussian Naive Bayes
nb_prob = gnb_mod.predict_proba(X_test)[:,-1]
nb_auc = roc_auc_score(y_test, nb_prob)
print("Gaussian Naive Bayes AUC: ", nb_auc)
nb_fpr, nb_tpr, _ = roc_curve(y_test, nb_prob)
# Out:
# Gaussian Naive Bayes AUC:  0.758893280632411

# %%
# gradient boosting
gb_prob = gb_mod.predict_proba(X_test)[:,-1]
gb_auc = roc_auc_score(y_test, gb_prob)
print("GradientBoosting AUC: ", gb_auc)
gb_fpr, gb_tpr, _ = roc_curve(y_test, gb_prob)
# Out:
# GradientBoosting AUC:  0.7885375494071146

# %%
# Multi-Layer perceptron
mlp_prob = mlp_mod.predict_proba(X_test)[:,-1]
mlp_auc = roc_auc_score(y_test, mlp_prob)
print("MultiLayer Perceptron AUC: ", mlp_auc)
mlp_fpr, mlp_tpr, _ = roc_curve(y_test, mlp_prob)
# Out:
# MultiLayer Perceptron AUC:  0.8122529644268774

# %%
# Bagging tree
bg_prob = modelBagging.predict_proba(X_test)[:,-1]
bg_auc = roc_auc_score(y_test, bg_prob)
print("Bagging Tree AUC: ", bg_auc)
bg_fpr, bg_tpr, _ = roc_curve(y_test, bg_prob)
# Out:
# Bagging Tree AUC:  0.7905138339920948

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(12,8))
ax.plot(ns_fpr, ns_tpr, linestyle= '--', linewidth=3.0,label= 'Reference')
#ax.plot(rf_fpr, rf_tpr, linestyle= '-', linewidth=3.0,label= 'LSTM Classifier')
ax.plot(bg_fpr, bg_tpr, linestyle= '--', linewidth=3.0,label= 'Bagging Tree')
#ax.plot(LR8_fpr, LR8_tpr, linestyle='-', label= 'LogisticRegression')
ax.plot(nb_fpr, nb_tpr, linestyle='-', linewidth=3.0,label= 'GaussianNB')
ax.plot(gb_fpr, gb_tpr, linestyle='-',linewidth=3.0, label= 'Gradient Boosting')
ax.plot(mlp_fpr, mlp_tpr, linestyle='-', linewidth=3.0,label= 'MultiLayer Perceptron')
#ax.plot(ET8_fpr, ET8_tpr, linestyle='-', label= 'Extra Trees Classifier')
ax.plot(rf_fpr, rf_tpr, linestyle='-',linewidth=3.0, label= 'RandomForest Classifier')
plt.xticks(np.arange(0.0, 1.1, step=0.1),fontsize=16)
plt.xlabel('False Positve rate',fontsize=16)
plt.yticks(np.arange(0.0, 1.1, step=0.1),fontsize=16)
plt.ylabel('True Positive rate',fontsize=16)
#plt.title('ROC curve')
plt.title('ROC Curves', fontweight='bold', fontsize=16)
#plt.xlim([0,0.6])
#plt.ylim([0.9,1])
plt.legend(prop={'size':13}, loc='lower right')
#ax.legend(loc="bottom right",fontweight='bold')
plt.savefig('kds2019idcnn.png',dpi=100)

# %%
rf_prob = rf_mod.predict_proba(X_test)[:,-1]

nb_prob = gnb_mod.predict_proba(X_test)[:,-1]

gb_prob = gb_mod.predict_proba(X_test)[:,-1]

mlp_prob = mlp_mod.predict_proba(X_test)[:,-1]


bg_prob = modelBagging.predict_proba(X_test)[:,-1]



import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from sklearn.metrics import confusion_matrix, classification_report, average_precision_score, precision_recall_curve
from IPython.display import display

def plot_pr_curves(y_true, y_score_dict, size=(8, 5), average='weighted'):
    """
    Plots the precision-recall curve for a multiple estimators.
    :param y_true: True labels.
    :param y_score_dict: Dictionary containing the estimator name as keys and the predicted label probabilities
           as values.
    :param size: Size of the plot.
    :param average: Average parameter used for the calculation of the average precision score.
    :return: None
    """
    plt.figure(figsize=size)

    for name, y_score in y_score_dict.items():
        precisions, recalls, _ = precision_recall_curve(y_true, y_score)
        pr_auc = average_precision_score(y_true, y_score, average=average)
        plt.plot(recalls, precisions, label='{}'.format(name, pr_auc))

    plt.title('Precision / Recall Curve',fontsize=16)
    plt.xlabel('Recall',fontsize=16)
    plt.ylabel('Precision',fontsize=16)
    plt.legend(prop={'size':13},loc='lower left')
    plt.savefig('ROCs.png',dpi=100)


#################################################################LSTM #################################
plot_pr_curves(y_test, 
               {
                   'Gradient Boosting': rf_prob,
                   'BG Classifier': bg_prob,
                   'GaussianNB': nb_prob,
                   'GB Classifier': gb_prob,
                   'MultiLayer Perceptron': mlp_prob,
               }, 
               size=(12, 12))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished

# %%
#%%  submit results in table forms
rf_prob = rf_mod.predict_proba(X_test)[:,-1]
rf_auc = roc_auc_score(y_test,rf_prob)
print("RandomForest AUC: ", rf_auc)
rf_fpr, rf_tpr, _ = roc_curve(y_test, rf_prob)


nb_prob = gnb_mod.predict_proba(X_test)[:,-1]
nb_auc = roc_auc_score(y_test, nb_prob)
print("Gaussian Naive Bayes AUC: ", nb_auc)
nb_fpr, nb_tpr, _ = roc_curve(y_test, nb_prob)

gb_prob = gb_mod.predict_proba(X_test)[:,-1]
gb_auc = roc_auc_score(y_test, gb_prob)
print("GradientBoosting AUC: ", gb_auc)
gb_fpr, gb_tpr, _ = roc_curve(y_test, gb_prob)

mlp_prob = mlp_mod.predict_proba(X_test)[:,-1]
mlp_auc = roc_auc_score(y_test, mlp_prob)
print("MultiLayer Perceptron AUC: ", mlp_auc)
mlp_fpr, mlp_tpr, _ = roc_curve(y_test, mlp_prob)


bg_prob = modelBagging.predict_proba(X_test)[:,-1]
bg_auc = roc_auc_score(y_test, bg_prob)
print("Bagging Tree AUC: ", bg_auc)
bg_fpr, bg_tpr, _ = roc_curve(y_test, bg_prob)


from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score

models = {
    'Random Classifier':rf_mod, 
    'Extra Classifier': ExtraTreesClassifier,
    'Gaussian Naive Bayes': gnb_mod,
    'Gradient Boosting':gb_mod,
    'Multi-Layer Perceptron':mlp_mod,
    'Bagging Trees':modelBagging
    
}

columns = [
    'accuracy',
    'precision',
    'recall',
    'f1'
]

table = {}


for model in models.keys():
    
    pred = models[model].predict(X_test)
    accuracy = models[model].score(X_test,y_test)
    precision = precision_score(y_test,pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test,pred)
    
    table[model] = [accuracy, precision, recall, f1]
    
results = pd.DataFrame.from_dict(table, orient='index')
results.columns = columns
results
# Out:
# RandomForest AUC:  0.8073122529644269
# Gaussian Naive Bayes AUC:  0.758893280632411
# GradientBoosting AUC:  0.7885375494071146
# MultiLayer Perceptron AUC:  0.8122529644268774
# Bagging Tree AUC:  0.7905138339920948
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
#                         accuracy  precision    recall        f1
# Random Classifier       0.842105   0.893617  0.913043  0.903226
# Extra Classifier        0.859649   0.895833  0.934783  0.914894
# Gaussian Naive Bayes    0.807018   0.843137  0.934783  0.886598
# Gradient Boosting       0.877193   0.897959  0.956522  0.926316
# Multi-Layer Perceptron  0.842105   0.877551  0.934783  0.905263
# Bagging Trees           0.824561   0.928571  0.847826  0.886364
